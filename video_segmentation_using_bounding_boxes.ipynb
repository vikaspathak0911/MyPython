# %% [markdown]
# <a href="https://colab.research.google.com/github/vikaspathak0911/MyPython/blob/main/video_segmentation_using_bounding_boxes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# --- 2. Install Dependencies ---
# %pip install opencv-python ultralytics

import cv2
import os
from collections import deque
from ultralytics import YOLO
import math

print("Libraries installed and imported successfully.")

# --- 3. Configuration ---
# IMPORTANT:
# 1. Replace 'path/to/your/judo_video.mp4' with the actual path to your video
#    in Google Drive.
#    Example: '/content/drive/My Drive/Judo_Videos/my_judo_match.mp4'
# 2. The OUTPUT_DIR will be created in your Google Drive.
#    Example: '/content/drive/My Drive/Judo_Clips_Output'

VIDEO_PATH = '/content/drive/My Drive/Japan vs South Korea .mp4' # <--- CHANGE THIS TO YOUR VIDEO PATH
OUTPUT_DIR = '/content/drive/My Drive/Judo_Throw_Clips_With_Boxes'    # <--- OUTPUT DIRECTORY IN YOUR DRIVE

CLIP_DURATION_SECONDS = 5      # Total clip length (e.g., 4-6 seconds)
PRE_EVENT_SECONDS = 2          # Seconds before the event to include (adjust as needed)
POST_EVENT_SECONDS = CLIP_DURATION_SECONDS - PRE_EVENT_SECONDS # Seconds after the event

# Bounding box ratio threshold for throw detection (height < ratio * width)
# This is the most crucial parameter to tune.
# Experiment with values like 0.8, 0.9, 0.95 depending on your video angles.
BOUNDING_BOX_RATIO_THRESHOLD = 0.9

# New parameters for filtering closest central persons:
# Max distance from frame center (as a fraction of frame diagonal) for a person to be considered "central".
# Tune this value: 0.2 means center of bbox must be within 20% of diagonal from frame center.
MAX_CENTER_DISTANCE_RATIO = 0.25
# Minimum required confidence for person detection (YOLOv8's output confidence)
# If you're not seeing boxes, try lowering this (e.g., to 0.4 or 0.3)
PERSON_CONFIDENCE_THRESHOLD = 0.5

# Bounding box visualization color and thickness for the output clips
# Using Bright Red for clear visibility during debugging. Change to Green (0,255,0) later if desired.
BOUNDING_BOX_COLOR = (0, 0, 255)  # Bright Red color (BGR format: Blue, Green, Red)
BOUNDING_BOX_THICKNESS = 5        # Make it thicker

# --- Ensure output directory exists in Google Drive ---
os.makedirs(OUTPUT_DIR, exist_ok=True)
print(f"Output directory set to: {OUTPUT_DIR}")

# --- 4. Initialize YOLOv8 Model ---
yolo_model = YOLO('yolov8n.pt') # You can try 'yolov8s.pt' if you have a good GPU runtime.

person_class_id = None
for class_id, class_name in yolo_model.names.items():
    if class_name == 'person':
        person_class_id = class_id
        break

if person_class_id is None:
    raise ValueError("Could not find 'person' class in the YOLO model's names. Check model configuration.")
print(f"YOLOv8 model loaded. 'person' class ID: {person_class_id}")


# --- 5. Helper Functions ---

def get_all_person_bounding_boxes(frame, model, person_id, conf_thresh):
    """
    Uses YOLOv8 to detect ALL people in a frame and return their bounding boxes
    with confidence scores.
    Returns a list of dictionaries: [{'bbox': [x1,y1,x2,y2], 'conf': conf_score}]
    """
    results = model(frame, verbose=False, conf=conf_thresh, device=0)
    person_detections = []
    for r in results:
        for *xyxy, conf, cls in r.boxes.data:
            if int(cls) == person_id:
                person_detections.append({'bbox': [int(xyxy[0]), int(xyxy[1]), int(xyxy[2]), int(xyxy[3])],
                                          'conf': float(conf)})
    return person_detections

def calculate_bbox_dimensions_and_center(bbox):
    """Calculates width, height, area, and center from [x_min, y_min, x_max, y_max]."""
    x_min, y_min, x_max, y_max = bbox
    width = x_max - x_min
    height = y_max - y_min
    area = width * height
    center_x = (x_min + x_max) // 2
    center_y = (y_min + y_max) // 2
    return width, height, area, (center_x, center_y)

def select_closest_central_persons(person_detections, frame_center, frame_diagonal_length, max_center_dist_ratio):
    """
    Filters and selects up to two closest persons who are also near the center of the frame.
    Returns a list of dictionaries, each containing 'bbox', 'width', 'height', 'area', 'center'.
    """
    central_persons_data = []

    for detection in person_detections:
        bbox = detection['bbox']
        width, height, area, bbox_center = calculate_bbox_dimensions_and_center(bbox)

        if width <= 0 or height <= 0 or area <= 0:
            continue

        dist_from_frame_center = math.sqrt(
            (bbox_center[0] - frame_center[0])**2 + (bbox_center[1] - frame_center[1])**2
        )

        if dist_from_frame_center <= max_center_dist_ratio * frame_diagonal_length:
            central_persons_data.append({
                'bbox': bbox,
                'area': area,
                'dist_from_center': dist_from_frame_center,
                'width': width,
                'height': height,
                'center': bbox_center
            })

    central_persons_data.sort(key=lambda x: x['area'], reverse=True)

    return central_persons_data[:2]

def extract_clip_with_frames(output_dir, frames, fps, clip_index, video_dimensions):
    """Extracts and saves a video clip using a list of pre-processed frames."""
    fourcc = cv2.VideoWriter_fourcc(*'mp4v') # Codec for .mp4, commonly used
    clip_filename = os.path.join(output_dir, f"throw_clip_{clip_index:04d}.mp4")

    out = cv2.VideoWriter(clip_filename, fourcc, fps, video_dimensions)

    frames_written = 0
    for frame in frames:
        if frame is None:
            print(f"Warning: Attempted to write a None frame for clip {clip_index}")
            continue
        try:
            out.write(frame)
            frames_written += 1
        except Exception as e:
            print(f"Error writing frame to {clip_filename}: {e}")
            break

    out.release()
    print(f"Saved clip: {clip_filename} (Wrote {frames_written} frames)")


# --- 6. Main Processing Logic ---

def process_video_for_throws(video_path, output_dir, clip_duration, pre_event_duration, post_event_duration,
                              bbox_ratio_threshold, yolo_model, person_class_id,
                              max_center_dist_ratio, person_conf_threshold,
                              bounding_box_color, bounding_box_thickness):
    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        print(f"Error: Could not open video {video_path}. Please check the path and permissions.")
        return

    fps = cap.get(cv2.CAP_PROP_FPS)
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    video_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    video_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    video_dimensions = (video_width, video_height)

    frame_center = (video_width // 2, video_height // 2)
    frame_diagonal_length = math.sqrt(video_width**2 + video_height**2)

    print(f"Video opened: {video_path}")
    print(f"FPS: {fps}, Total Frames: {total_frames}, Dimensions: {video_dimensions}")
    print(f"Frame Center: {frame_center}, Diagonal Length: {frame_diagonal_length:.2f}")


    pre_event_frames = int(pre_event_duration * fps)
    post_event_frames = int(post_event_duration * fps)
    total_clip_frames = int(clip_duration * fps)

    clip_count = 0
    event_detected_frame = -1

    current_frame_num = 0
    while True:
        ret, frame = cap.read()
        if not ret:
            print("End of video stream or read error.")
            break

        if event_detected_frame != -1 and current_frame_num < event_detected_frame + post_event_frames:
             current_frame_num += 1
             continue

        all_person_detections = get_all_person_bounding_boxes(frame, yolo_model, person_class_id, person_conf_threshold)
        selected_persons_data = select_closest_central_persons(
            all_person_detections, frame_center, frame_diagonal_length, MAX_CENTER_DISTANCE_RATIO
        )

        throw_detected_in_frame = False
        relevant_bboxes = []
        for person_data in selected_persons_data:
            bbox = person_data['bbox']
            relevant_bboxes.append(bbox)
            width = person_data['width']
            height = person_data['height']
            if width > 0 and height > 0:
                if height < bbox_ratio_threshold * width:
                    throw_detected_in_frame = True
                    break

        if throw_detected_in_frame:
            print(f"\nPotential throw detected at frame: {current_frame_num}")
            event_detected_frame = current_frame_num
            clip_count += 1

            clip_start_frame = max(0, event_detected_frame - pre_event_frames)
            clip_end_frame = clip_start_frame + total_clip_frames - 1
            clip_end_frame = min(clip_end_frame, total_frames - 1)

            actual_clip_length_frames = clip_end_frame - clip_start_frame + 1
            if actual_clip_length_frames < total_clip_frames:
                 clip_start_frame = max(0, clip_end_frame - total_clip_frames + 1)
                 actual_clip_length_frames = clip_end_frame - clip_start_frame + 1

            print(f"  Attempting to extract clip {clip_count}: from frame {clip_start_frame} to {clip_end_frame} (Actual length: {actual_clip_length_frames} frames)")

            frames_for_clip = []
            temp_cap = cv2.VideoCapture(video_path)
            temp_cap.set(cv2.CAP_PROP_POS_FRAMES, clip_start_frame)

            for i in range(clip_start_frame, clip_end_frame + 1):
                ret_temp, frame_temp = temp_cap.read()
                if not ret_temp:
                    print(f"Warning: Could not read frame {i} for clip {clip_count}. Ending clip early.")
                    break

                # Re-run detection for each frame in the clip to ensure boxes are consistent
                all_person_detections_clip = get_all_person_bounding_boxes(frame_temp, yolo_model, person_class_id, person_conf_threshold)
                selected_persons_data_clip = select_closest_central_persons(
                    all_person_detections_clip, frame_center, frame_diagonal_length, MAX_CENTER_DISTANCE_RATIO
                )

                # --- Draw bounding boxes on the frame_temp ---
                if selected_persons_data_clip:
                    # Print statement to confirm drawing for *this specific frame*
                    print(f"    Drawing {len(selected_persons_data_clip)} boxes on frame {i} of clip {clip_count}")
                    for person_data_clip in selected_persons_data_clip:
                        bbox_clip = person_data_clip['bbox']
                        x_min_clip, y_min_clip, x_max_clip, y_max_clip = bbox_clip
                        # Robustly clamp coordinates to be within frame bounds
                        x_min_clip = max(0, x_min_clip)
                        y_min_clip = max(0, y_min_clip)
                        x_max_clip = min(video_width - 1, x_max_clip) # -1 because max coordinate is width-1
                        y_max_clip = min(video_height - 1, y_max_clip) # -1 because max coordinate is height-1

                        cv2.rectangle(frame_temp, (x_min_clip, y_min_clip), (x_max_clip, y_max_clip),
                                      bounding_box_color, bounding_box_thickness)
                else:
                    # Print statement if no persons are selected for drawing on this frame
                    print(f"    No persons selected for drawing on frame {i} of clip {clip_count}")

                frames_for_clip.append(frame_temp)
            temp_cap.release()

            extract_clip_with_frames(output_dir, frames_for_clip, fps, clip_count, video_dimensions)

        current_frame_num += 1

    cap.release()
    print("\nVideo processing finished. All potential clips with bounding boxes extracted.")

# --- 7. Run the processing ---
if __name__ == "__main__":
    print("Starting judo throw clip extraction with bounding box visualization...")
    process_video_for_throws(
        video_path=VIDEO_PATH,
        output_dir=OUTPUT_DIR,
        clip_duration=CLIP_DURATION_SECONDS,
        pre_event_duration=PRE_EVENT_SECONDS,
        post_event_duration=POST_EVENT_SECONDS,
#     Drawing 2 boxes on frame 25498 of clip 190
#     Drawing 2 boxes on frame 25499 of clip 190
#     Drawing 2 boxes on frame 25500 of clip 190
#     Drawing 2 boxes on frame 25501 of clip 190
#     Drawing 2 boxes on frame 25502 of clip 190
#     Drawing 2 boxes on frame 25503 of clip 190
#     Drawing 2 boxes on frame 25504 of clip 190
#     Drawing 2 boxes on frame 25505 of clip 190
#     Drawing 2 boxes on frame 25506 of clip 190
#     Drawing 2 boxes on frame 25507 of clip 190
#     Drawing 2 boxes on frame 25508 of clip 190
#     Drawing 2 boxes on frame 25509 of clip 190
#     Drawing 2 boxes on frame 25510 of clip 190
#     Drawing 2 boxes on frame 25511 of clip 190
#     Drawing 2 boxes on frame 25512 of clip 190
#     Drawing 2 boxes on frame 25513 of clip 190
#     Drawing 2 boxes on frame 25514 of clip 190
#     Drawing 2 boxes on frame 25515 of clip 190
#     Drawing 2 boxes on frame 25516 of clip 190
#     Drawing 2 boxes on frame 25517 of clip 190
#     Drawing 2 boxes on frame 25518 of clip 190
#     Drawing 2 boxes on frame 25519 of clip 190
#     Drawing 2 boxes on frame 25520 of clip 190
#     Drawing 2 boxes on frame 25521 of clip 190
#     Drawing 2 boxes on frame 25522 of clip 190
#     Drawing 2 boxes on frame 25523 of clip 190
#     Drawing 2 boxes on frame 25524 of clip 190
#     Drawing 2 boxes on frame 25525 of clip 190
#     Drawing 2 boxes on frame 25526 of clip 190
#     Drawing 2 boxes on frame 25527 of clip 190
#     Drawing 2 boxes on frame 25528 of clip 190
#     Drawing 2 boxes on frame 25529 of clip 190
#     Drawing 2 boxes on frame 25530 of clip 190
#     Drawing 2 boxes on frame 25531 of clip 190
#     Drawing 2 boxes on frame 25532 of clip 190
#     Drawing 2 boxes on frame 25533 of clip 190
#     Drawing 2 boxes on frame 25534 of clip 190
#     Drawing 2 boxes on frame 25535 of clip 190
#     Drawing 2 boxes on frame 25536 of clip 190
#     Drawing 2 boxes on frame 25537 of clip 190
#     Drawing 2 boxes on frame 25538 of clip 190
#     Drawing 2 boxes on frame 25539 of clip 190
#     Drawing 2 boxes on frame 25540 of clip 190
#     Drawing 2 boxes on frame 25541 of clip 190
#     Drawing 2 boxes on frame 25542 of clip 190
#     Drawing 2 boxes on frame 25543 of clip 190
#     Drawing 2 boxes on frame 25544 of clip 190
#     Drawing 2 boxes on frame 25545 of clip 190
#     Drawing 2 boxes on frame 25546 of clip 190
#     Drawing 2 boxes on frame 25547 of clip 190
#     Drawing 2 boxes on frame 25548 of clip 190
#     Drawing 2 boxes on frame 25549 of clip 190
#     Drawing 2 boxes on frame 25550 of clip 190
#     Drawing 2 boxes on frame 25551 of clip 190
#     Drawing 2 boxes on frame 25552 of clip 190
#     Drawing 2 boxes on frame 25553 of clip 190
#     Drawing 2 boxes on frame 25554 of clip 190
#     Drawing 2 boxes on frame 25555 of clip 190
#     Drawing 2 boxes on frame 25556 of clip 190
#     Drawing 2 boxes on frame 25557 of clip 190
#     Drawing 2 boxes on frame 25558 of clip 190
#     Drawing 2 boxes on frame 25559 of clip 190
#     Drawing 2 boxes on frame 25560 of clip 190
#     Drawing 2 boxes on frame 25561 of clip 190
#     Drawing 2 boxes on frame 25562 of clip 190
#     Drawing 2 boxes on frame 25563 of clip 190
#     Drawing 2 boxes on frame 25564 of clip 190
#     Drawing 2 boxes on frame 25565 of clip 190
#     Drawing 2 boxes on frame 25566 of clip 190
#     Drawing 2 boxes on frame 25567 of clip 190
#     Drawing 2 boxes on frame 25568 of clip 190
#     Drawing 2 boxes on frame 25569 of clip 190
#     Drawing 2 boxes on frame 25570 of clip 190
#     Drawing 2 boxes on frame 25571 of clip 190
#     Drawing 2 boxes on frame 25572 of clip 190
#     Drawing 2 boxes on frame 25573 of clip 190
#     Drawing 2 boxes on frame 25574 of clip 190
#     Drawing 2 boxes on frame 25575 of clip 190
#     Drawing 2 boxes on frame 25576 of clip 190
#     Drawing 2 boxes on frame 25577 of clip 190
#     Drawing 2 boxes on frame 25578 of clip 190
#     Drawing 2 boxes on frame 25579 of clip 190
#     Drawing 1 boxes on frame 25580 of clip 190
#     Drawing 1 boxes on frame 25581 of clip 190
#     Drawing 2 boxes on frame 25582 of clip 190
#     Drawing 2 boxes on frame 25583 of clip 190
#     Drawing 2 boxes on frame 25584 of clip 190
#     Drawing 2 boxes on frame 25585 of clip 190
#     Drawing 2 boxes on frame 25586 of clip 190
#     Drawing 2 boxes on frame 25587 of clip 190
#     Drawing 2 boxes on frame 25588 of clip 190
#     Drawing 2 boxes on frame 25589 of clip 190
#     Drawing 2 boxes on frame 25590 of clip 190
#     Drawing 2 boxes on frame 25591 of clip 190
#     Drawing 2 boxes on frame 25592 of clip 190
#     Drawing 2 boxes on frame 25593 of clip 190
#     Drawing 1 boxes on frame 25594 of clip 190
#     Drawing 1 boxes on frame 25595 of clip 190
#     Drawing 1 boxes on frame 25596 of clip 190
#     Drawing 1 boxes on frame 25597 of clip 190
#     Drawing 1 boxes on frame 25598 of clip 190
#     Drawing 2 boxes on frame 25599 of clip 190
#     Drawing 1 boxes on frame 25600 of clip 190
#     Drawing 2 boxes on frame 25601 of clip 190
#     Drawing 2 boxes on frame 25602 of clip 190
#     Drawing 2 boxes on frame 25603 of clip 190
#     Drawing 2 boxes on frame 25604 of clip 190
#     Drawing 2 boxes on frame 25605 of clip 190
#     Drawing 2 boxes on frame 25606 of clip 190
#     Drawing 2 boxes on frame 25607 of clip 190
#     Drawing 2 boxes on frame 25608 of clip 190
#     Drawing 2 boxes on frame 25609 of clip 190
#     Drawing 2 boxes on frame 25610 of clip 190
#     Drawing 2 boxes on frame 25611 of clip 190
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips_With_Boxes/throw_clip_0190.mp4 (Wrote 125 frames)
#
# Potential throw detected at frame: 25622
#   Attempting to extract clip 191: from frame 25572 to 25696 (Actual length: 125 frames)
#     Drawing 2 boxes on frame 25572 of clip 191
#     Drawing 2 boxes on frame 25573 of clip 191
#     Drawing 2 boxes on frame 25574 of clip 191
#     Drawing 2 boxes on frame 25575 of clip 191
#     Drawing 2 boxes on frame 25576 of clip 191
#     Drawing 2 boxes on frame 25577 of clip 191
#     Drawing 2 boxes on frame 25578 of clip 191
#     Drawing 2 boxes on frame 25579 of clip 191
#     Drawing 1 boxes on frame 25580 of clip 191
#     Drawing 1 boxes on frame 25581 of clip 191
#     Drawing 1 boxes on frame 31463 of clip 222
#     No persons selected for drawing on frame 31464 of clip 222
#     No persons selected for drawing on frame 31465 of clip 222
#     Drawing 1 boxes on frame 31466 of clip 222
#     No persons selected for drawing on frame 31467 of clip 222
#     No persons selected for drawing on frame 31468 of clip 222
#     No persons selected for drawing on frame 31469 of clip 222
#     Drawing 1 boxes on frame 31470 of clip 222
#     Drawing 1 boxes on frame 31471 of clip 222
#     No persons selected for drawing on frame 31472 of clip 222
#     No persons selected for drawing on frame 31473 of clip 222
#     No persons selected for drawing on frame 31474 of clip 222
#     No persons selected for drawing on frame 31475 of clip 222
#     No persons selected for drawing on frame 31476 of clip 222
#     No persons selected for drawing on frame 31477 of clip 222
#     No persons selected for drawing on frame 31478 of clip 222
#     No persons selected for drawing on frame 31479 of clip 222
#     No persons selected for drawing on frame 31480 of clip 222
#     No persons selected for drawing on frame 31481 of clip 222
#     No persons selected for drawing on frame 31482 of clip 222
#     No persons selected for drawing on frame 31483 of clip 222
#     Drawing 2 boxes on frame 31484 of clip 222
#     Drawing 2 boxes on frame 31485 of clip 222
#     Drawing 2 boxes on frame 31486 of clip 222
#     Drawing 2 boxes on frame 31487 of clip 222
#     Drawing 2 boxes on frame 31488 of clip 222
#     Drawing 2 boxes on frame 31489 of clip 222
#     Drawing 2 boxes on frame 31490 of clip 222
#     Drawing 2 boxes on frame 31491 of clip 222
#     Drawing 2 boxes on frame 31492 of clip 222
#     Drawing 2 boxes on frame 31493 of clip 222
#     Drawing 2 boxes on frame 31494 of clip 222
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips_With_Boxes/throw_clip_0222.mp4 (Wrote 125 frames)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-003670620241> in <cell line: 0>()
#     267 if __name__ == "__main__":
#     268     print("Starting judo throw clip extraction with bounding box visualization...")
# --> 269     process_video_for_throws(
#     270         video_path=VIDEO_PATH,
#     271         output_dir=OUTPUT_DIR,
#
# <ipython-input-2-003670620241> in process_video_for_throws(video_path, output_dir, clip_duration, pre_event_duration, post_event_duration, bbox_ratio_threshold, yolo_model, person_class_id, max_center_dist_ratio, person_conf_threshold, bounding_box_color, bounding_box_thickness)
#     186              continue
#     187
# --> 188         all_person_detections = get_all_person_bounding_boxes(frame, yolo_model, person_class_id, person_conf_threshold)
#     189         selected_persons_data = select_closest_central_persons(
#     190             all_person_detections, frame_center, frame_diagonal_length, MAX_CENTER_DISTANCE_RATIO
#
# <ipython-input-2-003670620241> in get_all_person_bounding_boxes(frame, model, person_id, conf_thresh)
#      69     Returns a list of dictionaries: [{'bbox': [x1,y1,x2,y2], 'conf': conf_score}]
#      70     """
# ---> 71     results = model(frame, verbose=False, conf=conf_thresh, device=0)
#      72     person_detections = []
#      73     for r in results:
#
# /usr/local/lib/python3.11/dist-packages/ultralytics/engine/model.py in __call__(self, source, stream, **kwargs)
#     183             ...     print(f"Detected {len(r)} objects in image")
#     184         """
# --> 185         return self.predict(source, stream, **kwargs)
#     186
#     187     @staticmethod
#
# /usr/local/lib/python3.11/dist-packages/ultralytics/engine/model.py in predict(self, source, stream, predictor, **kwargs)
#     553         if prompts and hasattr(self.predictor, "set_prompts"):  # for SAM-type models
#     554             self.predictor.set_prompts(prompts)
# --> 555         return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#     556
#     557     def track(
#
# /usr/local/lib/python3.11/dist-packages/ultralytics/engine/predictor.py in __call__(self, source, model, stream, *args, **kwargs)
#     225             return self.stream_inference(source, model, *args, **kwargs)
#     226         else:
# --> 227             return list(self.stream_inference(source, model, *args, **kwargs))  # merge list of Result into one
#     228
#     229     def predict_cli(self, source=None, model=None):
#
# /usr/local/lib/python3.11/dist-packages/torch/utils/_contextlib.py in generator_context(*args, **kwargs)
#      34             # Issuing `None` to a generator fires it up
#      35             with ctx_factory():
# ---> 36                 response = gen.send(None)
#      37
#      38             while True:
#
# /usr/local/lib/python3.11/dist-packages/ultralytics/engine/predictor.py in stream_inference(self, source, model, *args, **kwargs)
#     328                 # Inference
#     329                 with profilers[1]:
# --> 330                     preds = self.inference(im, *args, **kwargs)
#     331                     if self.args.embed:
#     332                         yield from [preds] if isinstance(preds, torch.Tensor) else preds  # yield embedding tensors
#
# /usr/local/lib/python3.11/dist-packages/ultralytics/engine/predictor.py in inference(self, im, *args, **kwargs)
#     180             else False
#     181         )
# --> 182         return self.model(im, augment=self.args.augment, visualize=visualize, embed=self.args.embed, *args, **kwargs)
#     183
#     184     def pre_transform(self, im: List[np.ndarray]) -> List[np.ndarray]:
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#    1741     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1748                 or _global_backward_pre_hooks or _global_backward_hooks
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#    1752         result = None
#
# /usr/local/lib/python3.11/dist-packages/ultralytics/nn/autobackend.py in forward(self, im, augment, visualize, embed, **kwargs)
#     634         # PyTorch
#     635         if self.pt or self.nn_module:
# --> 636             y = self.model(im, augment=augment, visualize=visualize, embed=embed, **kwargs)
#     637
#     638         # TorchScript
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#    1741     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1748                 or _global_backward_pre_hooks or _global_backward_hooks
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#    1752         result = None
#
# /usr/local/lib/python3.11/dist-packages/ultralytics/nn/tasks.py in forward(self, x, *args, **kwargs)
#     136         if isinstance(x, dict):  # for cases of training and validating while training.
#     137             return self.loss(x, *args, **kwargs)
# --> 138         return self.predict(x, *args, **kwargs)
#     139
#     140     def predict(self, x, profile=False, visualize=False, augment=False, embed=None):
#
# /usr/local/lib/python3.11/dist-packages/ultralytics/nn/tasks.py in predict(self, x, profile, visualize, augment, embed)
#     154         if augment:
#     155             return self._predict_augment(x)
# --> 156         return self._predict_once(x, profile, visualize, embed)
#     157
#     158     def _predict_once(self, x, profile=False, visualize=False, embed=None):
#
# /usr/local/lib/python3.11/dist-packages/ultralytics/nn/tasks.py in _predict_once(self, x, profile, visualize, embed)
#     177             if profile:
#     178                 self._profile_one_layer(m, x, dt)
# --> 179             x = m(x)  # run
#     180             y.append(x if m.i in self.save else None)  # save output
#     181             if visualize:
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#    1741     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1748                 or _global_backward_pre_hooks or _global_backward_hooks
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#    1752         result = None
#
# /usr/local/lib/python3.11/dist-packages/ultralytics/nn/modules/head.py in forward(self, x)
#     118
#     119         for i in range(self.nl):
# --> 120             x[i] = torch.cat((self.cv2[i](x[i]), self.cv3[i](x[i])), 1)
#     121         if self.training:  # Training path
#     122             return x
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in __getattr__(self, name)
#    1913     # on `torch.nn.Module` and all its subclasses is largely disabled as a result. See:
#    1914     # https://github.com/pytorch/pytorch/pull/115074
# -> 1915     def __getattr__(self, name: str) -> Union[Tensor, "Module"]:
#    1916         if "_parameters" in self.__dict__:
#    1917             _parameters = self.__dict__["_parameters"]
#
# KeyboardInterrupt:

# %%
# --- 2. Install Dependencies ---
# %pip install opencv-python ultralytics

import cv2
import os
from collections import deque
from ultralytics import YOLO
import math

print("Libraries installed and imported successfully.")
# Out:
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.11/dist-packages (4.11.0.86)
# Requirement already satisfied: ultralytics in /usr/local/lib/python3.11/dist-packages (8.3.152)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.11/dist-packages (from opencv-python) (2.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (11.2.1)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (1.15.3)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.6.0+cu124)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (0.21.0+cu124)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.11/dist-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.2.2)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.0.14)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.58.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2025.4.26)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (4.14.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Libraries installed and imported successfully.

# %%
# --- 3. Configuration ---
VIDEO_PATH = '/content/drive/My Drive/Japan vs South Korea .mp4' # <--- CHANGE THIS TO YOUR VIDEO PATH
OUTPUT_DIR = '/content/drive/My Drive/Judo_Throw_Clips'    # <--- OUTPUT DIRECTORY IN YOUR DRIVE

CLIP_DURATION_SECONDS = 10    # Total clip length (e.g., 4-6 seconds)
PRE_EVENT_SECONDS = 5       # Seconds before the event to include
POST_EVENT_SECONDS = CLIP_DURATION_SECONDS - PRE_EVENT_SECONDS

BOUNDING_BOX_RATIO_THRESHOLD = 0.9 # Tune this: height < ratio * width for throw detection

# New parameters for filtering closest central persons:
# Max distance from frame center (as a fraction of frame diagonal) for a person to be considered "central".
# Tune this value: 0.2 means center of bbox must be within 20% of diagonal from frame center.
MAX_CENTER_DISTANCE_RATIO = 0.25
# Minimum required confidence for person detection
PERSON_CONFIDENCE_THRESHOLD = 0.5

# Bounding box visualization color and thickness for the output clips
BOUNDING_BOX_COLOR = (0, 255, 0)  # Green color (BGR format: Blue, Green, Red)
BOUNDING_BOX_THICKNESS = 2

# --- Ensure output directory exists in Google Drive ---
os.makedirs(OUTPUT_DIR, exist_ok=True)
print(f"Output directory set to: {OUTPUT_DIR}")
# Out:
# Output directory set to: /content/drive/My Drive/Judo_Throw_Clips

# %%
# --- 4. Initialize YOLOv8 Model ---
yolo_model = YOLO('yolov8n.pt') # Using nano for speed. Consider 'yolov8s.pt' for better accuracy.

person_class_id = None
for class_id, class_name in yolo_model.names.items():
    if class_name == 'person':
        person_class_id = class_id
        break

if person_class_id is None:
    raise ValueError("Could not find 'person' class in the YOLO model's names. Check model configuration.")
print(f"YOLOv8 model loaded. 'person' class ID: {person_class_id}")
# Out:
# YOLOv8 model loaded. 'person' class ID: 0

# %%
# --- 5. Helper Functions ---

def get_all_person_bounding_boxes(frame, model, person_id, conf_thresh):
    """
    Uses YOLOv8 to detect ALL people in a frame and return their bounding boxes
    with confidence scores.
    Returns a list of dictionaries: [{'bbox': [x1,y1,x2,y2], 'conf': conf_score}]
    """
    results = model(frame, verbose=False, conf=conf_thresh, device=0) # conf threshold applied here
    person_detections = []
    for r in results:
        for *xyxy, conf, cls in r.boxes.data:
            if int(cls) == person_id:
                person_detections.append({'bbox': [int(xyxy[0]), int(xyxy[1]), int(xyxy[2]), int(xyxy[3])],
                                          'conf': float(conf)})
    return person_detections

def calculate_bbox_dimensions_and_center(bbox):
    """Calculates width, height, area, and center from [x_min, y_min, x_max, y_max]."""
    x_min, y_min, x_max, y_max = bbox
    width = x_max - x_min
    height = y_max - y_min
    area = width * height
    center_x = (x_min + x_max) // 2
    center_y = (y_min + y_max) // 2
    return width, height, area, (center_x, center_y)

def distance(p1, p2):
    """Calculates Euclidean distance between two points."""
    return math.sqrt((p1[0] - p2[0])**2 + (p1[1] - p2[1])**2)

def select_closest_central_persons(person_detections, frame_center, frame_diagonal_length, max_center_dist_ratio):
    """
    Filters and selects up to two closest persons who are also near the center of the frame.
    """
    central_persons_data = [] # Stores (bbox, area, distance_from_center) for central persons

    for detection in person_detections:
        bbox = detection['bbox']
        width, height, area, bbox_center = calculate_bbox_dimensions_and_center(bbox)

        # Skip invalid bounding boxes
        if width <= 0 or height <= 0 or area <= 0:
            continue

        dist_from_frame_center = distance(bbox_center, frame_center)

        # Check if the person is "central" enough
        if dist_from_frame_center <= max_center_dist_ratio * frame_diagonal_length:
            central_persons_data.append({
                'bbox': bbox,
                'area': area,
                'dist_from_center': dist_from_frame_center,
                'width': width,
                'height': height
            })

    # Sort central persons by area in descending order (largest area means likely closest)
    central_persons_data.sort(key=lambda x: x['area'], reverse=True)

    # Return the top two (or fewer if less are available) bounding boxes
    return [p['bbox'] for p in central_persons_data[:2]]


def extract_clip(video_path, output_dir, start_frame, end_frame, fps, clip_index, video_dimensions):
    """Extracts and saves a video clip."""
    cap = cv2.VideoCapture(video_path)
    cap.set(cv2.CAP_PROP_POS_FRAMES, start_frame)

    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    clip_filename = os.path.join(output_dir, f"throw_clip_{clip_index:04d}.mp4")

    out = cv2.VideoWriter(clip_filename, fourcc, fps, video_dimensions)

    current_frame_num = start_frame
    frames_written = 0
    while cap.isOpened() and current_frame_num <= end_frame:
        ret, frame = cap.read()
        if not ret:
            # This can happen if the requested end_frame is beyond the actual video length
            # or if there's a read error.
            # print(f"Warning: Reached end of video or failed to read at frame {current_frame_num}")
            break
        try:
            out.write(frame)
            frames_written += 1
        except Exception as e:
            print(f"Error writing frame {current_frame_num} to {clip_filename}: {e}")
            break

        current_frame_num += 1

    out.release()
    cap.release()
    print(f"Saved clip: {clip_filename} (Frames: {start_frame}-{current_frame_num-1}, Written: {frames_written})")

# %%
# --- 6. Main Processing Logic ---

def process_video_for_throws(video_path, output_dir, clip_duration, pre_event_duration, post_event_duration,
                              bbox_ratio_threshold, yolo_model, person_class_id,
                              max_center_dist_ratio, person_conf_threshold):
    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        print(f"Error: Could not open video {video_path}. Please check the path and permissions.")
        return

    fps = cap.get(cv2.CAP_PROP_FPS)
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    video_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    video_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    video_dimensions = (video_width, video_height)

    # Calculate frame center and diagonal length for centrality checks
    frame_center = (video_width // 2, video_height // 2)
    frame_diagonal_length = math.sqrt(video_width**2 + video_height**2)

    print(f"Video opened: {video_path}")
    print(f"FPS: {fps}, Total Frames: {total_frames}, Dimensions: {video_dimensions}")
    print(f"Frame Center: {frame_center}, Diagonal Length: {frame_diagonal_length:.2f}")


    pre_event_frames = int(pre_event_duration * fps)
    post_event_frames = int(post_event_duration * fps)
    total_clip_frames = int(clip_duration * fps)

    clip_count = 0
    event_detected_frame = -1

    current_frame_num = 0
    while True:
        ret, frame = cap.read()
        if not ret:
            print("End of video stream or read error.")
            break

        # If we are within a recently extracted clip's timeframe, skip processing
        if event_detected_frame != -1 and current_frame_num < event_detected_frame + post_event_frames:
             current_frame_num += 1
             continue

        # 1. Get ALL person detections first
        all_person_detections = get_all_person_bounding_boxes(frame, yolo_model, person_class_id, person_conf_threshold)

        # 2. Filter and select the two closest central persons
        selected_bboxes = select_closest_central_persons(
            all_person_detections, frame_center, frame_diagonal_length, MAX_CENTER_DISTANCE_RATIO
        )

        throw_detected_in_frame = False
        if len(selected_bboxes) >= 1: # We need at least one person to check the throw condition
            for bbox in selected_bboxes:
                width, height = calculate_bbox_dimensions_and_center(bbox)[0:2] # Get width and height

                if width > 0 and height > 0:
                    if height < bbox_ratio_threshold * width:
                        throw_detected_in_frame = True
                        # print(f"  Triggering bbox (W={width}, H={height}, Ratio={height/width:.2f})")
                        break # Found one person satisfying the condition, so consider it a potential event

        if throw_detected_in_frame:
            print(f"\nPotential throw detected at frame: {current_frame_num}")
            event_detected_frame = current_frame_num
            clip_count += 1

            clip_start_frame = max(0, event_detected_frame - pre_event_frames)
            clip_end_frame = clip_start_frame + total_clip_frames - 1
            clip_end_frame = min(clip_end_frame, total_frames - 1)

            actual_clip_length_frames = clip_end_frame - clip_start_frame + 1
            if actual_clip_length_frames < total_clip_frames:
                 clip_start_frame = max(0, clip_end_frame - total_clip_frames + 1)
                 actual_clip_length_frames = clip_end_frame - clip_start_frame + 1 # Recalculate

            print(f"  Attempting to extract clip {clip_count}: from frame {clip_start_frame} to {clip_end_frame} (Actual length: {actual_clip_length_frames} frames)")

            extract_clip(video_path, output_dir, clip_start_frame, clip_end_frame, fps, clip_count, video_dimensions)

        current_frame_num += 1

    cap.release()
    print("\nVideo processing finished. All potential clips extracted.")

# %%
# --- 7. Run the processing ---
if __name__ == "__main__":
    print("Starting judo throw clip extraction with refined person detection...")
    process_video_for_throws(
        video_path=VIDEO_PATH,
        output_dir=OUTPUT_DIR,
        clip_duration=CLIP_DURATION_SECONDS,
        pre_event_duration=PRE_EVENT_SECONDS,
        post_event_duration=POST_EVENT_SECONDS,
        bbox_ratio_threshold=BOUNDING_BOX_RATIO_THRESHOLD,
        yolo_model=yolo_model,
        person_class_id=person_class_id,
        max_center_dist_ratio=MAX_CENTER_DISTANCE_RATIO,
        person_conf_threshold=PERSON_CONFIDENCE_THRESHOLD
    )
    print("Process complete. Check your Google Drive for the clips.")
# Out:
# Starting judo throw clip extraction with refined person detection...
# Video opened: /content/drive/My Drive/Japan vs South Korea .mp4
# FPS: 25.0, Total Frames: 59520, Dimensions: (1280, 720)
# Frame Center: (640, 360), Diagonal Length: 1468.60
#
# Potential throw detected at frame: 513
#   Attempting to extract clip 1: from frame 388 to 637 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0001.mp4 (Frames: 388-637, Written: 250)
#
# Potential throw detected at frame: 638
#   Attempting to extract clip 2: from frame 513 to 762 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0002.mp4 (Frames: 513-762, Written: 250)
#
# Potential throw detected at frame: 1350
#   Attempting to extract clip 3: from frame 1225 to 1474 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0003.mp4 (Frames: 1225-1474, Written: 250)
#
# Potential throw detected at frame: 1475
#   Attempting to extract clip 4: from frame 1350 to 1599 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0004.mp4 (Frames: 1350-1599, Written: 250)
#
# Potential throw detected at frame: 2167
#   Attempting to extract clip 5: from frame 2042 to 2291 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0005.mp4 (Frames: 2042-2291, Written: 250)
#
# Potential throw detected at frame: 2546
#   Attempting to extract clip 6: from frame 2421 to 2670 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0006.mp4 (Frames: 2421-2670, Written: 250)
#
# Potential throw detected at frame: 2671
#   Attempting to extract clip 7: from frame 2546 to 2795 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0007.mp4 (Frames: 2546-2795, Written: 250)
#
# Potential throw detected at frame: 2796
#   Attempting to extract clip 8: from frame 2671 to 2920 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0008.mp4 (Frames: 2671-2920, Written: 250)
#
# Potential throw detected at frame: 3015
#   Attempting to extract clip 9: from frame 2890 to 3139 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0009.mp4 (Frames: 2890-3139, Written: 250)
#
# Potential throw detected at frame: 3146
#   Attempting to extract clip 10: from frame 3021 to 3270 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0010.mp4 (Frames: 3021-3270, Written: 250)
#
# Potential throw detected at frame: 3421
#   Attempting to extract clip 11: from frame 3296 to 3545 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0011.mp4 (Frames: 3296-3545, Written: 250)
#
# Potential throw detected at frame: 3656
#   Attempting to extract clip 12: from frame 3531 to 3780 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0012.mp4 (Frames: 3531-3780, Written: 250)
#
# Potential throw detected at frame: 3786
#   Attempting to extract clip 13: from frame 3661 to 3910 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0013.mp4 (Frames: 3661-3910, Written: 250)
#
# Potential throw detected at frame: 3911
#   Attempting to extract clip 14: from frame 3786 to 4035 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0014.mp4 (Frames: 3786-4035, Written: 250)
#
# Potential throw detected at frame: 4058
#   Attempting to extract clip 15: from frame 3933 to 4182 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0015.mp4 (Frames: 3933-4182, Written: 250)
#
# Potential throw detected at frame: 4377
#   Attempting to extract clip 16: from frame 4252 to 4501 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0016.mp4 (Frames: 4252-4501, Written: 250)
#
# Potential throw detected at frame: 4502
#   Attempting to extract clip 17: from frame 4377 to 4626 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0017.mp4 (Frames: 4377-4626, Written: 250)
#
# Potential throw detected at frame: 4627
#   Attempting to extract clip 18: from frame 4502 to 4751 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0018.mp4 (Frames: 4502-4751, Written: 250)
#
# Potential throw detected at frame: 4768
#   Attempting to extract clip 19: from frame 4643 to 4892 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0019.mp4 (Frames: 4643-4892, Written: 250)
#
# Potential throw detected at frame: 4930
#   Attempting to extract clip 20: from frame 4805 to 5054 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0020.mp4 (Frames: 4805-5054, Written: 250)
#
# Potential throw detected at frame: 5055
#   Attempting to extract clip 21: from frame 4930 to 5179 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0021.mp4 (Frames: 4930-5179, Written: 250)
#
# Potential throw detected at frame: 5181
#   Attempting to extract clip 22: from frame 5056 to 5305 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0022.mp4 (Frames: 5056-5305, Written: 250)
#
# Potential throw detected at frame: 5318
#   Attempting to extract clip 23: from frame 5193 to 5442 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0023.mp4 (Frames: 5193-5442, Written: 250)
#
# Potential throw detected at frame: 5623
#   Attempting to extract clip 24: from frame 5498 to 5747 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0024.mp4 (Frames: 5498-5747, Written: 250)
#
# Potential throw detected at frame: 5780
#   Attempting to extract clip 25: from frame 5655 to 5904 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0025.mp4 (Frames: 5655-5904, Written: 250)
#
# Potential throw detected at frame: 6033
#   Attempting to extract clip 26: from frame 5908 to 6157 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0026.mp4 (Frames: 5908-6157, Written: 250)
#
# Potential throw detected at frame: 6158
#   Attempting to extract clip 27: from frame 6033 to 6282 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0027.mp4 (Frames: 6033-6282, Written: 250)
#
# Potential throw detected at frame: 6285
#   Attempting to extract clip 28: from frame 6160 to 6409 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0028.mp4 (Frames: 6160-6409, Written: 250)
#
# Potential throw detected at frame: 6420
#   Attempting to extract clip 29: from frame 6295 to 6544 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0029.mp4 (Frames: 6295-6544, Written: 250)
#
# Potential throw detected at frame: 6547
#   Attempting to extract clip 30: from frame 6422 to 6671 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0030.mp4 (Frames: 6422-6671, Written: 250)
#
# Potential throw detected at frame: 6792
#   Attempting to extract clip 31: from frame 6667 to 6916 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0031.mp4 (Frames: 6667-6916, Written: 250)
#
# Potential throw detected at frame: 6974
#   Attempting to extract clip 32: from frame 6849 to 7098 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0032.mp4 (Frames: 6849-7098, Written: 250)
#
# Potential throw detected at frame: 7099
#   Attempting to extract clip 33: from frame 6974 to 7223 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0033.mp4 (Frames: 6974-7223, Written: 250)
#
# Potential throw detected at frame: 7224
#   Attempting to extract clip 34: from frame 7099 to 7348 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0034.mp4 (Frames: 7099-7348, Written: 250)
#
# Potential throw detected at frame: 7372
#   Attempting to extract clip 35: from frame 7247 to 7496 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0035.mp4 (Frames: 7247-7496, Written: 250)
#
# Potential throw detected at frame: 7789
#   Attempting to extract clip 36: from frame 7664 to 7913 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0036.mp4 (Frames: 7664-7913, Written: 250)
#
# Potential throw detected at frame: 7914
#   Attempting to extract clip 37: from frame 7789 to 8038 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0037.mp4 (Frames: 7789-8038, Written: 250)
#
# Potential throw detected at frame: 8071
#   Attempting to extract clip 38: from frame 7946 to 8195 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0038.mp4 (Frames: 7946-8195, Written: 250)
#
# Potential throw detected at frame: 8196
#   Attempting to extract clip 39: from frame 8071 to 8320 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0039.mp4 (Frames: 8071-8320, Written: 250)
#
# Potential throw detected at frame: 8330
#   Attempting to extract clip 40: from frame 8205 to 8454 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0040.mp4 (Frames: 8205-8454, Written: 250)
#
# Potential throw detected at frame: 8469
#   Attempting to extract clip 41: from frame 8344 to 8593 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0041.mp4 (Frames: 8344-8593, Written: 250)
#
# Potential throw detected at frame: 8612
#   Attempting to extract clip 42: from frame 8487 to 8736 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0042.mp4 (Frames: 8487-8736, Written: 250)
#
# Potential throw detected at frame: 8766
#   Attempting to extract clip 43: from frame 8641 to 8890 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0043.mp4 (Frames: 8641-8890, Written: 250)
#
# Potential throw detected at frame: 9033
#   Attempting to extract clip 44: from frame 8908 to 9157 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0044.mp4 (Frames: 8908-9157, Written: 250)
#
# Potential throw detected at frame: 9162
#   Attempting to extract clip 45: from frame 9037 to 9286 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0045.mp4 (Frames: 9037-9286, Written: 250)
#
# Potential throw detected at frame: 9385
#   Attempting to extract clip 46: from frame 9260 to 9509 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0046.mp4 (Frames: 9260-9509, Written: 250)
#
# Potential throw detected at frame: 9510
#   Attempting to extract clip 47: from frame 9385 to 9634 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0047.mp4 (Frames: 9385-9634, Written: 250)
#
# Potential throw detected at frame: 9674
#   Attempting to extract clip 48: from frame 9549 to 9798 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0048.mp4 (Frames: 9549-9798, Written: 250)
#
# Potential throw detected at frame: 9807
#   Attempting to extract clip 49: from frame 9682 to 9931 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0049.mp4 (Frames: 9682-9931, Written: 250)
#
# Potential throw detected at frame: 10019
#   Attempting to extract clip 50: from frame 9894 to 10143 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0050.mp4 (Frames: 9894-10143, Written: 250)
#
# Potential throw detected at frame: 10183
#   Attempting to extract clip 51: from frame 10058 to 10307 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0051.mp4 (Frames: 10058-10307, Written: 250)
#
# Potential throw detected at frame: 10377
#   Attempting to extract clip 52: from frame 10252 to 10501 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0052.mp4 (Frames: 10252-10501, Written: 250)
#
# Potential throw detected at frame: 10502
#   Attempting to extract clip 53: from frame 10377 to 10626 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0053.mp4 (Frames: 10377-10626, Written: 250)
#
# Potential throw detected at frame: 10826
#   Attempting to extract clip 54: from frame 10701 to 10950 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0054.mp4 (Frames: 10701-10950, Written: 250)
#
# Potential throw detected at frame: 10968
#   Attempting to extract clip 55: from frame 10843 to 11092 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0055.mp4 (Frames: 10843-11092, Written: 250)
#
# Potential throw detected at frame: 11629
#   Attempting to extract clip 56: from frame 11504 to 11753 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0056.mp4 (Frames: 11504-11753, Written: 250)
#
# Potential throw detected at frame: 11867
#   Attempting to extract clip 57: from frame 11742 to 11991 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0057.mp4 (Frames: 11742-11991, Written: 250)
#
# Potential throw detected at frame: 11998
#   Attempting to extract clip 58: from frame 11873 to 12122 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0058.mp4 (Frames: 11873-12122, Written: 250)
#
# Potential throw detected at frame: 12344
#   Attempting to extract clip 59: from frame 12219 to 12468 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0059.mp4 (Frames: 12219-12468, Written: 250)
#
# Potential throw detected at frame: 12469
#   Attempting to extract clip 60: from frame 12344 to 12593 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0060.mp4 (Frames: 12344-12593, Written: 250)
#
# Potential throw detected at frame: 12963
#   Attempting to extract clip 61: from frame 12838 to 13087 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0061.mp4 (Frames: 12838-13087, Written: 250)
#
# Potential throw detected at frame: 13088
#   Attempting to extract clip 62: from frame 12963 to 13212 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0062.mp4 (Frames: 12963-13212, Written: 250)
#
# Potential throw detected at frame: 13218
#   Attempting to extract clip 63: from frame 13093 to 13342 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0063.mp4 (Frames: 13093-13342, Written: 250)
#
# Potential throw detected at frame: 13372
#   Attempting to extract clip 64: from frame 13247 to 13496 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0064.mp4 (Frames: 13247-13496, Written: 250)
#
# Potential throw detected at frame: 13756
#   Attempting to extract clip 65: from frame 13631 to 13880 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0065.mp4 (Frames: 13631-13880, Written: 250)
#
# Potential throw detected at frame: 14041
#   Attempting to extract clip 66: from frame 13916 to 14165 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0066.mp4 (Frames: 13916-14165, Written: 250)
#
# Potential throw detected at frame: 14166
#   Attempting to extract clip 67: from frame 14041 to 14290 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0067.mp4 (Frames: 14041-14290, Written: 250)
#
# Potential throw detected at frame: 14331
#   Attempting to extract clip 68: from frame 14206 to 14455 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0068.mp4 (Frames: 14206-14455, Written: 250)
#
# Potential throw detected at frame: 14773
#   Attempting to extract clip 69: from frame 14648 to 14897 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0069.mp4 (Frames: 14648-14897, Written: 250)
#
# Potential throw detected at frame: 14898
#   Attempting to extract clip 70: from frame 14773 to 15022 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0070.mp4 (Frames: 14773-15022, Written: 250)
#
# Potential throw detected at frame: 15114
#   Attempting to extract clip 71: from frame 14989 to 15238 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0071.mp4 (Frames: 14989-15238, Written: 250)
#
# Potential throw detected at frame: 15239
#   Attempting to extract clip 72: from frame 15114 to 15363 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0072.mp4 (Frames: 15114-15363, Written: 250)
#
# Potential throw detected at frame: 15367
#   Attempting to extract clip 73: from frame 15242 to 15491 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0073.mp4 (Frames: 15242-15491, Written: 250)
#
# Potential throw detected at frame: 15492
#   Attempting to extract clip 74: from frame 15367 to 15616 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0074.mp4 (Frames: 15367-15616, Written: 250)
#
# Potential throw detected at frame: 15617
#   Attempting to extract clip 75: from frame 15492 to 15741 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0075.mp4 (Frames: 15492-15741, Written: 250)
#
# Potential throw detected at frame: 16064
#   Attempting to extract clip 76: from frame 15939 to 16188 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0076.mp4 (Frames: 15939-16188, Written: 250)
#
# Potential throw detected at frame: 16202
#   Attempting to extract clip 77: from frame 16077 to 16326 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0077.mp4 (Frames: 16077-16326, Written: 250)
#
# Potential throw detected at frame: 16327
#   Attempting to extract clip 78: from frame 16202 to 16451 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0078.mp4 (Frames: 16202-16451, Written: 250)
#
# Potential throw detected at frame: 16453
#   Attempting to extract clip 79: from frame 16328 to 16577 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0079.mp4 (Frames: 16328-16577, Written: 250)
#
# Potential throw detected at frame: 16655
#   Attempting to extract clip 80: from frame 16530 to 16779 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0080.mp4 (Frames: 16530-16779, Written: 250)
#
# Potential throw detected at frame: 16786
#   Attempting to extract clip 81: from frame 16661 to 16910 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0081.mp4 (Frames: 16661-16910, Written: 250)
#
# Potential throw detected at frame: 16920
#   Attempting to extract clip 82: from frame 16795 to 17044 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0082.mp4 (Frames: 16795-17044, Written: 250)
#
# Potential throw detected at frame: 17054
#   Attempting to extract clip 83: from frame 16929 to 17178 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0083.mp4 (Frames: 16929-17178, Written: 250)
#
# Potential throw detected at frame: 17341
#   Attempting to extract clip 84: from frame 17216 to 17465 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0084.mp4 (Frames: 17216-17465, Written: 250)
#
# Potential throw detected at frame: 17474
#   Attempting to extract clip 85: from frame 17349 to 17598 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0085.mp4 (Frames: 17349-17598, Written: 250)
#
# Potential throw detected at frame: 17631
#   Attempting to extract clip 86: from frame 17506 to 17755 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0086.mp4 (Frames: 17506-17755, Written: 250)
#
# Potential throw detected at frame: 17856
#   Attempting to extract clip 87: from frame 17731 to 17980 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0087.mp4 (Frames: 17731-17980, Written: 250)
#
# Potential throw detected at frame: 18053
#   Attempting to extract clip 88: from frame 17928 to 18177 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0088.mp4 (Frames: 17928-18177, Written: 250)
#
# Potential throw detected at frame: 18254
#   Attempting to extract clip 89: from frame 18129 to 18378 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0089.mp4 (Frames: 18129-18378, Written: 250)
#
# Potential throw detected at frame: 18383
#   Attempting to extract clip 90: from frame 18258 to 18507 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0090.mp4 (Frames: 18258-18507, Written: 250)
#
# Potential throw detected at frame: 18508
#   Attempting to extract clip 91: from frame 18383 to 18632 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0091.mp4 (Frames: 18383-18632, Written: 250)
#
# Potential throw detected at frame: 18639
#   Attempting to extract clip 92: from frame 18514 to 18763 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0092.mp4 (Frames: 18514-18763, Written: 250)
#
# Potential throw detected at frame: 18945
#   Attempting to extract clip 93: from frame 18820 to 19069 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0093.mp4 (Frames: 18820-19069, Written: 250)
#
# Potential throw detected at frame: 19130
#   Attempting to extract clip 94: from frame 19005 to 19254 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0094.mp4 (Frames: 19005-19254, Written: 250)
#
# Potential throw detected at frame: 19255
#   Attempting to extract clip 95: from frame 19130 to 19379 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0095.mp4 (Frames: 19130-19379, Written: 250)
#
# Potential throw detected at frame: 19380
#   Attempting to extract clip 96: from frame 19255 to 19504 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0096.mp4 (Frames: 19255-19504, Written: 250)
#
# Potential throw detected at frame: 19505
#   Attempting to extract clip 97: from frame 19380 to 19629 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0097.mp4 (Frames: 19380-19629, Written: 250)
#
# Potential throw detected at frame: 19630
#   Attempting to extract clip 98: from frame 19505 to 19754 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0098.mp4 (Frames: 19505-19754, Written: 250)
#
# Potential throw detected at frame: 19925
#   Attempting to extract clip 99: from frame 19800 to 20049 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0099.mp4 (Frames: 19800-20049, Written: 250)
#
# Potential throw detected at frame: 20050
#   Attempting to extract clip 100: from frame 19925 to 20174 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0100.mp4 (Frames: 19925-20174, Written: 250)
#
# Potential throw detected at frame: 20175
#   Attempting to extract clip 101: from frame 20050 to 20299 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0101.mp4 (Frames: 20050-20299, Written: 250)
#
# Potential throw detected at frame: 20316
#   Attempting to extract clip 102: from frame 20191 to 20440 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0102.mp4 (Frames: 20191-20440, Written: 250)
#
# Potential throw detected at frame: 20443
#   Attempting to extract clip 103: from frame 20318 to 20567 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0103.mp4 (Frames: 20318-20567, Written: 250)
#
# Potential throw detected at frame: 20568
#   Attempting to extract clip 104: from frame 20443 to 20692 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0104.mp4 (Frames: 20443-20692, Written: 250)
#
# Potential throw detected at frame: 20742
#   Attempting to extract clip 105: from frame 20617 to 20866 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0105.mp4 (Frames: 20617-20866, Written: 250)
#
# Potential throw detected at frame: 20926
#   Attempting to extract clip 106: from frame 20801 to 21050 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0106.mp4 (Frames: 20801-21050, Written: 250)
#
# Potential throw detected at frame: 21053
#   Attempting to extract clip 107: from frame 20928 to 21177 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0107.mp4 (Frames: 20928-21177, Written: 250)
#
# Potential throw detected at frame: 21181
#   Attempting to extract clip 108: from frame 21056 to 21305 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0108.mp4 (Frames: 21056-21305, Written: 250)
#
# Potential throw detected at frame: 21306
#   Attempting to extract clip 109: from frame 21181 to 21430 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0109.mp4 (Frames: 21181-21430, Written: 250)
#
# Potential throw detected at frame: 21632
#   Attempting to extract clip 110: from frame 21507 to 21756 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0110.mp4 (Frames: 21507-21756, Written: 250)
#
# Potential throw detected at frame: 21757
#   Attempting to extract clip 111: from frame 21632 to 21881 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0111.mp4 (Frames: 21632-21881, Written: 250)
#
# Potential throw detected at frame: 21902
#   Attempting to extract clip 112: from frame 21777 to 22026 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0112.mp4 (Frames: 21777-22026, Written: 250)
#
# Potential throw detected at frame: 22027
#   Attempting to extract clip 113: from frame 21902 to 22151 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0113.mp4 (Frames: 21902-22151, Written: 250)
#
# Potential throw detected at frame: 22152
#   Attempting to extract clip 114: from frame 22027 to 22276 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0114.mp4 (Frames: 22027-22276, Written: 250)
#
# Potential throw detected at frame: 22277
#   Attempting to extract clip 115: from frame 22152 to 22401 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0115.mp4 (Frames: 22152-22401, Written: 250)
#
# Potential throw detected at frame: 22409
#   Attempting to extract clip 116: from frame 22284 to 22533 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0116.mp4 (Frames: 22284-22533, Written: 250)
#
# Potential throw detected at frame: 22534
#   Attempting to extract clip 117: from frame 22409 to 22658 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0117.mp4 (Frames: 22409-22658, Written: 250)
#
# Potential throw detected at frame: 22659
#   Attempting to extract clip 118: from frame 22534 to 22783 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0118.mp4 (Frames: 22534-22783, Written: 250)
#
# Potential throw detected at frame: 22795
#   Attempting to extract clip 119: from frame 22670 to 22919 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0119.mp4 (Frames: 22670-22919, Written: 250)
#
# Potential throw detected at frame: 22920
#   Attempting to extract clip 120: from frame 22795 to 23044 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0120.mp4 (Frames: 22795-23044, Written: 250)
#
# Potential throw detected at frame: 23047
#   Attempting to extract clip 121: from frame 22922 to 23171 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0121.mp4 (Frames: 22922-23171, Written: 250)
#
# Potential throw detected at frame: 23172
#   Attempting to extract clip 122: from frame 23047 to 23296 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0122.mp4 (Frames: 23047-23296, Written: 250)
#
# Potential throw detected at frame: 23304
#   Attempting to extract clip 123: from frame 23179 to 23428 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0123.mp4 (Frames: 23179-23428, Written: 250)
#
# Potential throw detected at frame: 23429
#   Attempting to extract clip 124: from frame 23304 to 23553 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0124.mp4 (Frames: 23304-23553, Written: 250)
#
# Potential throw detected at frame: 23554
#   Attempting to extract clip 125: from frame 23429 to 23678 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0125.mp4 (Frames: 23429-23678, Written: 250)
#
# Potential throw detected at frame: 23679
#   Attempting to extract clip 126: from frame 23554 to 23803 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0126.mp4 (Frames: 23554-23803, Written: 250)
#
# Potential throw detected at frame: 24051
#   Attempting to extract clip 127: from frame 23926 to 24175 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0127.mp4 (Frames: 23926-24175, Written: 250)
#
# Potential throw detected at frame: 24236
#   Attempting to extract clip 128: from frame 24111 to 24360 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0128.mp4 (Frames: 24111-24360, Written: 250)
#
# Potential throw detected at frame: 24361
#   Attempting to extract clip 129: from frame 24236 to 24485 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0129.mp4 (Frames: 24236-24485, Written: 250)
#
# Potential throw detected at frame: 24723
#   Attempting to extract clip 130: from frame 24598 to 24847 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0130.mp4 (Frames: 24598-24847, Written: 250)
#
# Potential throw detected at frame: 24888
#   Attempting to extract clip 131: from frame 24763 to 25012 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0131.mp4 (Frames: 24763-25012, Written: 250)
#
# Potential throw detected at frame: 25100
#   Attempting to extract clip 132: from frame 24975 to 25224 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0132.mp4 (Frames: 24975-25224, Written: 250)
#
# Potential throw detected at frame: 25225
#   Attempting to extract clip 133: from frame 25100 to 25349 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0133.mp4 (Frames: 25100-25349, Written: 250)
#
# Potential throw detected at frame: 25537
#   Attempting to extract clip 134: from frame 25412 to 25661 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0134.mp4 (Frames: 25412-25661, Written: 250)
#
# Potential throw detected at frame: 25668
#   Attempting to extract clip 135: from frame 25543 to 25792 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0135.mp4 (Frames: 25543-25792, Written: 250)
#
# Potential throw detected at frame: 26251
#   Attempting to extract clip 136: from frame 26126 to 26375 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0136.mp4 (Frames: 26126-26375, Written: 250)
#
# Potential throw detected at frame: 26433
#   Attempting to extract clip 137: from frame 26308 to 26557 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0137.mp4 (Frames: 26308-26557, Written: 250)
#
# Potential throw detected at frame: 26569
#   Attempting to extract clip 138: from frame 26444 to 26693 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0138.mp4 (Frames: 26444-26693, Written: 250)
#
# Potential throw detected at frame: 27370
#   Attempting to extract clip 139: from frame 27245 to 27494 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0139.mp4 (Frames: 27245-27494, Written: 250)
#
# Potential throw detected at frame: 27500
#   Attempting to extract clip 140: from frame 27375 to 27624 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0140.mp4 (Frames: 27375-27624, Written: 250)
#
# Potential throw detected at frame: 27715
#   Attempting to extract clip 141: from frame 27590 to 27839 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0141.mp4 (Frames: 27590-27839, Written: 250)
#
# Potential throw detected at frame: 27912
#   Attempting to extract clip 142: from frame 27787 to 28036 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0142.mp4 (Frames: 27787-28036, Written: 250)
#
# Potential throw detected at frame: 28404
#   Attempting to extract clip 143: from frame 28279 to 28528 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0143.mp4 (Frames: 28279-28528, Written: 250)
#
# Potential throw detected at frame: 28529
#   Attempting to extract clip 144: from frame 28404 to 28653 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0144.mp4 (Frames: 28404-28653, Written: 250)
#
# Potential throw detected at frame: 28991
#   Attempting to extract clip 145: from frame 28866 to 29115 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0145.mp4 (Frames: 28866-29115, Written: 250)
#
# Potential throw detected at frame: 29304
#   Attempting to extract clip 146: from frame 29179 to 29428 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0146.mp4 (Frames: 29179-29428, Written: 250)
#
# Potential throw detected at frame: 29448
#   Attempting to extract clip 147: from frame 29323 to 29572 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0147.mp4 (Frames: 29323-29572, Written: 250)
#
# Potential throw detected at frame: 29573
#   Attempting to extract clip 148: from frame 29448 to 29697 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0148.mp4 (Frames: 29448-29697, Written: 250)
#
# Potential throw detected at frame: 29712
#   Attempting to extract clip 149: from frame 29587 to 29836 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0149.mp4 (Frames: 29587-29836, Written: 250)
#
# Potential throw detected at frame: 29848
#   Attempting to extract clip 150: from frame 29723 to 29972 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0150.mp4 (Frames: 29723-29972, Written: 250)
#
# Potential throw detected at frame: 29973
#   Attempting to extract clip 151: from frame 29848 to 30097 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0151.mp4 (Frames: 29848-30097, Written: 250)
#
# Potential throw detected at frame: 30098
#   Attempting to extract clip 152: from frame 29973 to 30222 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0152.mp4 (Frames: 29973-30222, Written: 250)
#
# Potential throw detected at frame: 30223
#   Attempting to extract clip 153: from frame 30098 to 30347 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0153.mp4 (Frames: 30098-30347, Written: 250)
#
# Potential throw detected at frame: 30380
#   Attempting to extract clip 154: from frame 30255 to 30504 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0154.mp4 (Frames: 30255-30504, Written: 250)
#
# Potential throw detected at frame: 31092
#   Attempting to extract clip 155: from frame 30967 to 31216 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0155.mp4 (Frames: 30967-31216, Written: 250)
#
# Potential throw detected at frame: 31226
#   Attempting to extract clip 156: from frame 31101 to 31350 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0156.mp4 (Frames: 31101-31350, Written: 250)
#
# Potential throw detected at frame: 31355
#   Attempting to extract clip 157: from frame 31230 to 31479 (Actual length: 250 frames)
# Saved clip: /content/drive/My Drive/Judo_Throw_Clips/throw_clip_0157.mp4 (Frames: 31230-31479, Written: 250)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-633e97319f58> in <cell line: 0>()
#       2 if __name__ == "__main__":
#       3     print("Starting judo throw clip extraction with refined person detection...")
# ----> 4     process_video_for_throws(
#       5         video_path=VIDEO_PATH,
#       6         output_dir=OUTPUT_DIR,
#
# <ipython-input-11-87554bf26666> in process_video_for_throws(video_path, output_dir, clip_duration, pre_event_duration, post_event_duration, bbox_ratio_threshold, yolo_model, person_class_id, max_center_dist_ratio, person_conf_threshold)
#      44
#      45         # 1. Get ALL person detections first
# ---> 46         all_person_detections = get_all_person_bounding_boxes(frame, yolo_model, person_class_id, person_conf_threshold)
#      47
#      48         # 2. Filter and select the two closest central persons
#
# <ipython-input-10-d21ece1a714b> in get_all_person_bounding_boxes(frame, model, person_id, conf_thresh)
#       7     Returns a list of dictionaries: [{'bbox': [x1,y1,x2,y2], 'conf': conf_score}]
#       8     """
# ----> 9     results = model(frame, verbose=False, conf=conf_thresh, device=0) # conf threshold applied here
#      10     person_detections = []
#      11     for r in results:
#
# /usr/local/lib/python3.11/dist-packages/ultralytics/engine/model.py in __call__(self, source, stream, **kwargs)
#     183             ...     print(f"Detected {len(r)} objects in image")
#     184         """
# --> 185         return self.predict(source, stream, **kwargs)
#     186
#     187     @staticmethod
#
# /usr/local/lib/python3.11/dist-packages/ultralytics/engine/model.py in predict(self, source, stream, predictor, **kwargs)
#     553         if prompts and hasattr(self.predictor, "set_prompts"):  # for SAM-type models
#     554             self.predictor.set_prompts(prompts)
# --> 555         return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#     556
#     557     def track(
#
# /usr/local/lib/python3.11/dist-packages/ultralytics/engine/predictor.py in __call__(self, source, model, stream, *args, **kwargs)
#     225             return self.stream_inference(source, model, *args, **kwargs)
#     226         else:
# --> 227             return list(self.stream_inference(source, model, *args, **kwargs))  # merge list of Result into one
#     228
#     229     def predict_cli(self, source=None, model=None):
#
# /usr/local/lib/python3.11/dist-packages/torch/utils/_contextlib.py in generator_context(*args, **kwargs)
#      34             # Issuing `None` to a generator fires it up
#      35             with ctx_factory():
# ---> 36                 response = gen.send(None)
#      37
#      38             while True:
#
# /usr/local/lib/python3.11/dist-packages/ultralytics/engine/predictor.py in stream_inference(self, source, model, *args, **kwargs)
#     324                 # Preprocess
#     325                 with profilers[0]:
# --> 326                     im = self.preprocess(im0s)
#     327
#     328                 # Inference
#
# /usr/local/lib/python3.11/dist-packages/ultralytics/engine/predictor.py in preprocess(self, im)
#     164                 im = im[..., ::-1]  # BGR to RGB
#     165             im = im.transpose((0, 3, 1, 2))  # BHWC to BCHW, (n, 3, h, w)
# --> 166             im = np.ascontiguousarray(im)  # contiguous
#     167             im = torch.from_numpy(im)
#     168
#
# KeyboardInterrupt:
